# %% [markdown]
# [![](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/itmorn/AI.handbook/blob/main/DL/torchvision/transforms/transforms.ipynb)

# %% [markdown]
# # 图像增强

# %% [markdown]
# ## Pad填充

# %%
from PIL import Image
import torchvision.transforms as T
orig_img = Image.open('astronaut.jpg')
T.Pad(padding=10)(orig_img)
# Out:
# <PIL.Image.Image image mode=RGB size=532x532>
